# %% [markdown]
# ### Baseline Logistic Regression Model
#
# ### Validation Set Performance
# | Metric | Score |
# |--------|-------|
# | ROC-AUC | 0.7494 |
# | Precision (class 1) | 0.16 |
# | Recall (class 1) | 0.68 |
# | F1 (class 1) | 0.26 |
# | Accuracy | 0.69 |
#
# ### Observations
# - Baseline model for comparison against more advanced models
# - model catches 68% of true defaulters (recall) but also only 16% of predicted defaulters actually default (precision)
# - trading precision for recall

# %% [markdown]
# ### Baseline Random Forest Model (max_depth = 10)
#
# ### Validation Set Performance
# | Metric | Score |
# |--------|-------|
# | ROC-AUC | 0.7414 |
# | Precision (class 1) | 0.17 |
# | Recall (class 1) | 0.62 |
# | F1 (class 1) | 0.27 |
# | Accuracy | 0.73 |
#
# ### Observations
# - performs worse than Logistic Regression on ROC-AUC and recall for class 1

# %% [markdown]
# ###  Random Forest Model (max_depth = 10, min_samples_leaf = 50)
#
# ### Validation Set Performance
# | Metric | Score |
# |--------|-------|
# | ROC-AUC | 0.749 |
# | Precision (class 1) | 0.19 |
# | Recall (class 1) | 0.56 |
# | F1 (class 1) | 0.29 |
# | Accuracy | 0.73 |
#
# ### Observations
# - performs worse than Logistic Regression on ROC-AUC and recall for class 1
# - want to maximize ROC-AUC and class 1 for recall, most important thing is to correctly identify likely defaulters
